# %% [markdown]
# # <center style="color: #003b7f"> Analyzing Temperature and Precipitation Patterns <br/> for Climate Assessment </center> <a class='tocSkip'>
#
# **MSDS 2023 Term 4 SLT1B** | Loraine Menorca, BJ Enrik Yepes
#
# This notebook is dedicated for the details of the data collection and cleaning process that serves as a supplementary to the main report of this project.
#
# **! Note:** This was ran using PySpark via AWS' EMR studio. Rerunning the entire notebook outside a similar environment is not advisable.
#
# ***

# %%
spark
# Out:
# VBox()
# Starting Spark application
# <table>
# <tbody><tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>5</td><td>application_1685926317650_0006</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-9-252.ap-southeast-2.compute.internal:20888/proxy/application_1685926317650_0006/" class="emr-proxy-link j-JVI9X8RXA6LR application_1685926317650_0006" emr-resource="j-JVI9X8RXA6LR
# " application-id="application_1685926317650_0006">Link</a></td><td><a target="_blank" href="http://ip-172-31-7-111.ap-southeast-2.compute.internal:8042/node/containerlogs/container_1685926317650_0006_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></tbody></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# <pyspark.sql.session.SparkSession object at 0x7efd58cd35d0>

# %%
# Import necessary libraries
from pyspark.sql.types import StructType, StructField, StringType, DoubleType
from pyspark.sql import functions as F
import pyspark.pandas as ps

from datetime import datetime
import pytz
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Set the timezone to Philippine time for timestamps on file saving
ph_tz = pytz.timezone('Asia/Manila')

# Get the current datetime in Philippine time
current_datetime = datetime.now(ph_tz)

# Convert the datetime to string
current_datetime_str = current_datetime.strftime('%Y-%m-%d_%H:%M')

# Print the current datetime as string
print(current_datetime_str)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 2023-06-05_14:50

# %% [markdown]
# # I. Location details
#
# As detailed in the main notebook report, **bdcc_lab2_main.ipynb**, under the Data Source section, there details on the location of the stations such as the country and country code were collected. The raw files were in .txt. format and were converted into CSV files for ease of processing.

# %%
# Read the raw file on location
fnames = spark.read.text('s3://noaa-ghcn-pds/ghcnd-countries.txt')

# %%
fnames.show()

# %% [markdown]
# **SAVE**

# %%
# FOR SAVING
out_fpath =  f"s3://bdcc-lab2-2023/ghcnd/ghcnd_countries.csv"
out_fpath

# %%
# Add new columns: Country and Country code
(fnames.withColumn('columns', F.split(fnames.value, ' '))
       .withColumn('code', F.col('columns')[0])
       .withColumn('country', F.col('columns')[1])
       .drop('columns', 'value')
).write.csv(out_fpath)

# %% [markdown]
# # II. Station details
#
# Similarly, details about the stations were the data on climate and weather events such as elevation, geographical coordinates, and their name were collected. The raw text file was converted into a CSV file.

# %%
# Read raw file on stations
fnames = spark.read.text('s3://noaa-ghcn-pds/ghcnd-stations.txt')

# %%
fnames.show(vertical=True, truncate=False)

# %% [markdown]
# **SAVE**

# %%
# For saving
out_fpath =  f"s3://bdcc-lab2-2023/ghcnd/ghcnd_stations.csv"
out_fpath

# %%
# Added columns on coordinates, elevation, and others
(fnames.withColumn('columns', F.split(F.trim(fnames.value), '  '))
       .withColumn('id', F.col('columns')[0])
       .withColumn('latitude', F.trim(F.col('columns')[1]).cast('float'))
       .withColumn('longitude', F.trim(F.col('columns')[2]).cast('float'))
       .withColumn('elevation', F.trim(F.col('columns')[3]).cast('float'))
       .withColumn('state', F.trim(F.col('columns')[4]))
       .withColumn('name', F.trim(F.col('columns')[5]))
       .withColumn('gsn_flag', F.trim(F.col('columns')[6]))
       .withColumn('hcn_gsn_flag', F.trim(F.col('columns')[7]))
       .withColumn('wmo_id', F.trim(F.col('columns')[8]))
       .drop('columns', 'value')
).write.csv(out_fpath)

# %% [markdown]
# # Raw data on Climate
#
# The main dataset was collected using the path: `'s3a://noaa-ghcn-pds/csv/by_year/20*'`.

# %%
# Read the raw CSV files
fpath = 's3a://noaa-ghcn-pds/csv/by_year/20*'
df = spark.read.csv(fpath, header=True, sep=',').withColumn('filename', F.input_file_name())
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Checker: expectation is total count > unique count because of duplicate IDs
df.select('filename', 'ID', 'DATE').agg(
    F.countDistinct('filename', 'ID', 'DATE').alias('unique_count'),
    F.count('*').alias('total_count')
).show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +------------+-----------+
# |unique_count|total_count|
# +------------+-----------+
# |   264665977|  871923626|
# +------------+-----------+

# %% [markdown]
# ## Elements
#
# The `ELEMENT` field contains the important features that are of interest. To enhance the ease of processing and performing aggregations, the data in this field has been transformed from rows to columns. Each feature now corresponds to a separate column, and the corresponding `DATA_VALUE` has been assigned as the value for each feature.

# %%
# Collect needed information on elements per record
df_elements = (df
                .select('filename', 'ID', 'DATE', 'ELEMENT', 'DATA_VALUE')
                .groupBy('filename', 'ID', 'DATE')
                .pivot('ELEMENT')
                .agg(F.first('DATA_VALUE'))
            )
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# ## Tags
#
# Because the original structure of the data is by `ID`, `DATE`, `ELEMENT`, and `DATA_VALUE`, the values of each tag are duplicated. Since the `ELEMENT` and `DATA_VALUE` columns were now flattened or transformed into unique records per row, the tags can now also be deduplicated.

# %%
# Collect needed information on tags per record
df_tags = (df
            .groupBy('ID', 'DATE')
            .agg(
                F.first("M_FLAG").alias("M_FLAG"),
                F.first("Q_FLAG").alias("Q_FLAG"),
                F.first("S_FLAG").alias("S_FLAG"),
                F.first("OBS_TIME").alias("OBS_TIME")
            )
        )
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# ## Merged Elements & Tags

# %%
# Merge information on elements and tags
df_final = df_tags.join(df_elements, on=['ID', 'DATE'], how="inner")
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# ## Supplementary
#
# The converted CSV files on the stations and country locations are now merged with the final data on climate and weather events.

# %%
fpath_stations =  f"s3://bdcc-lab2-2023/ghcnd/ghcnd_stations.csv"
fpath_countries =  f"s3://bdcc-lab2-2023/ghcnd/ghcnd_countries.csv"

# stations
schema_stations = StructType([
    StructField("ID", StringType(), nullable=True),
    StructField("LATITUDE", DoubleType(), nullable=True),
    StructField("LONGITUDE", DoubleType(), nullable=True),
    StructField("ELEVATION", DoubleType(), nullable=True),
    StructField("STATE", StringType(), nullable=True),
    StructField("NAME", StringType(), nullable=True),
    StructField("GSN_FLAG", StringType(), nullable=True),
    StructField("HCN_CRN", StringType(), nullable=True),
    StructField("WMO_ID", StringType(), nullable=True)
])

df_stations = spark.read.csv(fpath_stations, header=False, sep=',', schema=schema_stations)

# countries
schema_countries = StructType([
    StructField("COUNTRY_CODE", StringType(), nullable=True),
    StructField("COUNTRY", StringType(), nullable=True)
])
df_countries = spark.read.csv(fpath_countries, header=False, sep=',', schema=schema_countries)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Merged climate and weather events + Location + Station information
df_merged = (df_final
                .withColumn("COUNTRY_CODE", F.expr("substr(ID, 1, 2)"))
                .withColumn('DATE', F.to_date(F.col('DATE'), 'yyyyMMdd'))
                .withColumn('YEAR', F.year(F.col('DATE')))
                .withColumn('MONTH', F.month(F.col('DATE')))
                .withColumn('DAY', F.dayofmonth(F.col('DATE')))
                .join(df_stations, on='ID', how='left')
                .join(df_countries, on='COUNTRY_CODE', how='left')
            )
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df_merged.count()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 264665977

# %% [markdown]
# ## Save as Parquet

# %%
out_fpath =  f"s3://bdcc-lab2-2023/ghcnd/processed/ghcnd_processed_{current_datetime_str}.parquet"
out_fpath
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 's3://bdcc-lab2-2023/ghcnd/processed/ghcnd_processed_2023-06-05_14:50.parquet'

# %%
df_merged.write.parquet(out_fpath)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# ## Check saved data

# %%
in_fpath = f"s3://bdcc-lab2-2023/ghcnd/processed/ghcnd_processed_2023-06-05_14:50.parquet"
df_processed = spark.read.parquet(in_fpath)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# The schema of the preprocessed data. This would serve as the working file for succeeding steps in the project.

# %%
df_processed.printSchema()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- COUNTRY_CODE: string (nullable = true)
#  |-- ID: string (nullable = true)
#  |-- DATE: date (nullable = true)
#  |-- M_FLAG: string (nullable = true)
#  |-- Q_FLAG: string (nullable = true)
#  |-- S_FLAG: string (nullable = true)
#  |-- OBS_TIME: string (nullable = true)
#  |-- filename: string (nullable = true)
#  |-- ACMH: string (nullable = true)
#  |-- ACSH: string (nullable = true)
#  |-- ADPT: string (nullable = true)
#  |-- ASLP: string (nullable = true)
#  |-- ASTP: string (nullable = true)
#  |-- AWBT: string (nullable = true)
#  |-- AWDR: string (nullable = true)
#  |-- AWND: string (nullable = true)
#  |-- DAEV: string (nullable = true)
#  |-- DAPR: string (nullable = true)
#  |-- DASF: string (nullable = true)
#  |-- DATN: string (nullable = true)
#  |-- DATX: string (nullable = true)
#  |-- DAWM: string (nullable = true)
#  |-- DWPR: string (nullable = true)
#  |-- EVAP: string (nullable = true)
#  |-- FMTM: string (nullable = true)
#  |-- MDEV: string (nullable = true)
#  |-- MDPR: string (nullable = true)
#  |-- MDSF: string (nullable = true)
#  |-- MDTN: string (nullable = true)
#  |-- MDTX: string (nullable = true)
#  |-- MDWM: string (nullable = true)
#  |-- MNPN: string (nullable = true)
#  |-- MXPN: string (nullable = true)
#  |-- PGTM: string (nullable = true)
#  |-- PRCP: string (nullable = true)
#  |-- PSUN: string (nullable = true)
#  |-- RHAV: string (nullable = true)
#  |-- RHMN: string (nullable = true)
#  |-- RHMX: string (nullable = true)
#  |-- SN01: string (nullable = true)
#  |-- SN02: string (nullable = true)
#  |-- SN03: string (nullable = true)
#  |-- SN11: string (nullable = true)
#  |-- SN12: string (nullable = true)
#  |-- SN13: string (nullable = true)
#  |-- SN14: string (nullable = true)
#  |-- SN21: string (nullable = true)
#  |-- SN22: string (nullable = true)
#  |-- SN23: string (nullable = true)
#  |-- SN31: string (nullable = true)
#  |-- SN32: string (nullable = true)
#  |-- SN33: string (nullable = true)
#  |-- SN34: string (nullable = true)
#  |-- SN35: string (nullable = true)
#  |-- SN36: string (nullable = true)
#  |-- SN51: string (nullable = true)
#  |-- SN52: string (nullable = true)
#  |-- SN53: string (nullable = true)
#  |-- SN54: string (nullable = true)
#  |-- SN55: string (nullable = true)
#  |-- SN56: string (nullable = true)
#  |-- SN57: string (nullable = true)
#  |-- SNOW: string (nullable = true)
#  |-- SNWD: string (nullable = true)
#  |-- SX01: string (nullable = true)
#  |-- SX02: string (nullable = true)
#  |-- SX03: string (nullable = true)
#  |-- SX11: string (nullable = true)
#  |-- SX12: string (nullable = true)
#  |-- SX13: string (nullable = true)
#  |-- SX14: string (nullable = true)
#  |-- SX15: string (nullable = true)
#  |-- SX17: string (nullable = true)
#  |-- SX21: string (nullable = true)
#  |-- SX22: string (nullable = true)
#  |-- SX23: string (nullable = true)
#  |-- SX31: string (nullable = true)
#  |-- SX32: string (nullable = true)
#  |-- SX33: string (nullable = true)
#  |-- SX34: string (nullable = true)
#  |-- SX35: string (nullable = true)
#  |-- SX36: string (nullable = true)
#  |-- SX51: string (nullable = true)
#  |-- SX52: string (nullable = true)
#  |-- SX53: string (nullable = true)
#  |-- SX54: string (nullable = true)
#  |-- SX55: string (nullable = true)
#  |-- SX56: string (nullable = true)
#  |-- SX57: string (nullable = true)
#  |-- TAVG: string (nullable = true)
#  |-- THIC: string (nullable = true)
#  |-- TMAX: string (nullable = true)
#  |-- TMIN: string (nullable = true)
#  |-- TOBS: string (nullable = true)
#  |-- TSUN: string (nullable = true)
#  |-- WDF2: string (nullable = true)
#  |-- WDF5: string (nullable = true)
#  |-- WDFG: string (nullable = true)
#  |-- WDMV: string (nullable = true)
#  |-- WESD: string (nullable = true)
#  |-- WESF: string (nullable = true)
#  |-- WSF2: string (nullable = true)
#  |-- WSF5: string (nullable = true)
#  |-- WSFG: string (nullable = true)
#  |-- WSFI: string (nullable = true)
#  |-- WT01: string (nullable = true)
#  |-- WT02: string (nullable = true)
#  |-- WT03: string (nullable = true)
#  |-- WT04: string (nullable = true)
#  |-- WT05: string (nullable = true)
#  |-- WT06: string (nullable = true)
#  |-- WT07: string (nullable = true)
#  |-- WT08: string (nullable = true)
#  |-- WT09: string (nullable = true)
#  |-- WT10: string (nullable = true)
#  |-- WT11: string (nullable = true)
#  |-- WT12: string (nullable = true)
#  |-- WT13: string (nullable = true)
#  |-- WT14: string (nullable = true)
#  |-- WT15: string (nullable = true)
#  |-- WT16: string (nullable = true)
#  |-- WT17: string (nullable = true)
#  |-- WT18: string (nullable = true)
#  |-- WT19: string (nullable = true)
#  |-- WT21: string (nullable = true)
#  |-- WT22: string (nullable = true)
#  |-- WV01: string (nullable = true)
#  |-- WV03: string (nullable = true)
#  |-- WV07: string (nullable = true)
#  |-- WV18: string (nullable = true)
#  |-- WV20: string (nullable = true)
#  |-- YEAR: integer (nullable = true)
#  |-- MONTH: integer (nullable = true)
#  |-- DAY: integer (nullable = true)
#  |-- LATITUDE: double (nullable = true)
#  |-- LONGITUDE: double (nullable = true)
#  |-- ELEVATION: double (nullable = true)
#  |-- STATE: string (nullable = true)
#  |-- NAME: string (nullable = true)
#  |-- GSN_FLAG: string (nullable = true)
#  |-- HCN_CRN: string (nullable = true)
#  |-- WMO_ID: string (nullable = true)
#  |-- COUNTRY: string (nullable = true)

# %%
df_processed.show(vertical=True, truncate=False)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# -RECORD 0------------------------------------------------
#  COUNTRY_CODE | AS
#  ID           | ASN00030051
#  DATE         | 2000-08-06
#  M_FLAG       | null
#  Q_FLAG       | null
#  S_FLAG       | a
#  OBS_TIME     | null
#  filename     | s3a://noaa-ghcn-pds/csv/by_year/2000.csv
#  ACMH         | null
#  ACSH         | null
#  ADPT         | null
#  ASLP         | null
#  ASTP         | null
#  AWBT         | null
#  AWDR         | null
#  AWND         | null
#  DAEV         | null
#  DAPR         | null
#  DASF         | null
#  DATN         | null
#  DATX         | null
#  DAWM         | null
#  DWPR         | null
#  EVAP         | null
#  FMTM         | null
#  MDEV         | null
#  MDPR         | null
#  MDSF         | null
#  MDTN         | null
#  MDTX         | null
#  MDWM         | null
#  MNPN         | null
#  MXPN         | null
#  PGTM         | null
#  PRCP         | 0
#  PSUN         | null
#  RHAV         | null
#  RHMN         | null
#  RHMX         | null
#  SN01         | null
#  SN02         | null
#  SN03         | null
#  SN11         | null
#  SN12         | null
#  SN13         | null
#  SN14         | null
#  SN21         | null
#  SN22         | null
#  SN23         | null
#  SN31         | null
#  SN32         | null
#  SN33         | null
#  SN34         | null
#  SN35         | null
#  SN36         | null
#  SN51         | null
#  SN52         | null
#  SN53         | null
#  SN54         | null
#  SN55         | null
#  SN56         | null
#  SN57         | null
#  SNOW         | null
#  SNWD         | null
#  SX01         | null
#  SX02         | null
#  SX03         | null
#  SX11         | null
#  SX12         | null
#  SX13         | null
#  SX14         | null
#  SX15         | null
#  SX17         | null
#  SX21         | null
#  SX22         | null
#  SX23         | null
#  SX31         | null
#  SX32         | null
#  SX33         | null
#  SX34         | null
#  SX35         | null
#  SX36         | null
#  SX51         | null
#  SX52         | null
#  SX53         | null
#  SX54         | null
#  SX55         | null
#  SX56         | null
#  SX57         | null
#  TAVG         | null
#  THIC         | null
#  TMAX         | null
#  TMIN         | null
#  TOBS         | null
#  TSUN         | null
#  WDF2         | null
#  WDF5         | null
#  WDFG         | null
#  WDMV         | null
#  WESD         | null
#  WESF         | null
#  WSF2         | null
#  WSF5         | null
#  WSFG         | null
#  WSFI         | null
#  WT01         | null
#  WT02         | null
#  WT03         | null
#  WT04         | null
#  WT05         | null
#  WT06         | null
#  WT07         | null
#  WT08         | null
#  WT09         | null
#  WT10         | null
#  WT11         | null
#  WT12         | null
#  WT13         | null
#  WT14         | null
#  WT15         | null
#  WT16         | null
#  WT17         | null
#  WT18         | null
#  WT19         | null
#  WT21         | null
#  WT22         | null
#  WV01         | null
#  WV03         | null
#  WV07         | null
#  WV18         | null
#  WV20         | null
#  YEAR         | 2000
#  MONTH        | 8
#  DAY          | 6
#  LATITUDE     | null
#  LONGITUDE    | null
#  ELEVATION    | null
#  STATE        | null
#  NAME         | null
#  GSN_FLAG     | null
#  HCN_CRN      | null
#  WMO_ID       | null
#  COUNTRY      | Australia
# -RECORD 1------------------------------------------------
#  COUNTRY_CODE | BR
#  ID           | BR002043059
#  DATE         | 2000-01-11
#  M_FLAG       | null
#  Q_FLAG       | null
#  S_FLAG       | I
#  OBS_TIME     | null
#  filename     | s3a://noaa-ghcn-pds/csv/by_year/2000.csv
#  ACMH         | null
#  ACSH         | null
#  ADPT         | null
#  ASLP         | null
#  ASTP         | null
#  AWBT         | null
#  AWDR         | null
#  AWND         | null
#  DAEV         | null
#  DAPR         | null
#  DASF         | null
#  DATN         | null
#  DATX         | null
#  DAWM         | null
#  DWPR         | null
#  EVAP         | null
#  FMTM         | null
#  MDEV         | null
#  MDPR         | null
#  MDSF         | null
#  MDTN         | null
#  MDTX         | null
#  MDWM         | null
#  MNPN         | null
#  MXPN         | null
#  PGTM         | null
#  PRCP         | 0
#  PSUN         | null
#  RHAV         | null
#  RHMN         | null
#  RHMX         | null
#  SN01         | null
#  SN02         | null
#  SN03         | null
#  SN11         | null
#  SN12         | null
#  SN13         | null
#  SN14         | null
#  SN21         | null
#  SN22         | null
#  SN23         | null
#  SN31         | null
#  SN32         | null
#  SN33         | null
#  SN34         | null
#  SN35         | null
#  SN36         | null
#  SN51         | null
#  SN52         | null
#  SN53         | null
#  SN54         | null
#  SN55         | null
#  SN56         | null
#  SN57         | null
#  SNOW         | null
#  SNWD         | null
#  SX01         | null
#  SX02         | null
#  SX03         | null
#  SX11         | null
#  SX12         | null
#  SX13         | null
#  SX14         | null
#  SX15         | null
#  SX17         | null
#  SX21         | null
#  SX22         | null
#  SX23         | null
#  SX31         | null
#  SX32         | null
#  SX33         | null
#  SX34         | null
#  SX35         | null
#  SX36         | null
#  SX51         | null
#  SX52         | null
#  SX53         | null
#  SX54         | null
#  SX55         | null
#  SX56         | null
#  SX57         | null
#  TAVG         | null
#  THIC         | null
#  TMAX         | null
#  TMIN         | null
#  TOBS         | null
#  TSUN         | null
#  WDF2         | null
#  WDF5         | null
#  WDFG         | null
#  WDMV         | null
#  WESD         | null
#  WESF         | null
#  WSF2         | null
#  WSF5         | null
#  WSFG         | null
#  WSFI         | null
#  WT01         | null
#  WT02         | null
#  WT03         | null
#  WT04         | null
#  WT05         | null
#  WT06         | null
#  WT07         | null
#  WT08         | null
#  WT09         | null
#  WT10         | null
#  WT11         | null
#  WT12         | null
#  WT13         | null
#  WT14         | null
#  WT15         | null
#  WT16         | null
#  WT17         | null
#  WT18         | null
#  WT19         | null
#  WT21         | null
#  WT22         | null
#  WV01         | null
#  WV03         | null
#  WV07         | null
#  WV18         | null
#  WV20         | null
#  YEAR         | 2000
#  MONTH        | 1
#  DAY          | 11
#  LATITUDE     | null
#  LONGITUDE    | null
#  ELEVATION    | null
#  STATE        | null
#  NAME         | null
#  GSN_FLAG     | null
#  HCN_CRN      | null
#  WMO_ID       | null
#  COUNTRY      | Brazil
# -RECORD 2------------------------------------------------
#  COUNTRY_CODE | JA
#  ID           | JA000047656
#  DATE         | 2000-10-10
#  M_FLAG       | null
#  Q_FLAG       | null
#  S_FLAG       | S
#  OBS_TIME     | null
#  filename     | s3a://noaa-ghcn-pds/csv/by_year/2000.csv
#  ACMH         | null
#  ACSH         | null
#  ADPT         | null
#  ASLP         | null
#  ASTP         | null
#  AWBT         | null
#  AWDR         | null
#  AWND         | null
#  DAEV         | null
#  DAPR         | null
#  DASF         | null
#  DATN         | null
#  DATX         | null
#  DAWM         | null
#  DWPR         | null
#  EVAP         | null
#  FMTM         | null
#  MDEV         | null
#  MDPR         | null
#  MDSF         | null
#  MDTN         | null
#  MDTX         | null
#  MDWM         | null
#  MNPN         | null
#  MXPN         | null
#  PGTM         | null
#  PRCP         | null
#  PSUN         | null
#  RHAV         | null
#  RHMN         | null
#  RHMX         | null
#  SN01         | null
#  SN02         | null
#  SN03         | null
#  SN11         | null
#  SN12         | null
#  SN13         | null
#  SN14         | null
#  SN21         | null
#  SN22         | null
#  SN23         | null
#  SN31         | null
#  SN32         | null
#  SN33         | null
#  SN34         | null
#  SN35         | null
#  SN36         | null
#  SN51         | null
#  SN52         | null
#  SN53         | null
#  SN54         | null
#  SN55         | null
#  SN56         | null
#  SN57         | null
#  SNOW         | null
#  SNWD         | null
#  SX01         | null
#  SX02         | null
#  SX03         | null
#  SX11         | null
#  SX12         | null
#  SX13         | null
#  SX14         | null
#  SX15         | null
#  SX17         | null
#  SX21         | null
#  SX22         | null
#  SX23         | null
#  SX31         | null
#  SX32         | null
#  SX33         | null
#  SX34         | null
#  SX35         | null
#  SX36         | null
#  SX51         | null
#  SX52         | null
#  SX53         | null
#  SX54         | null
#  SX55         | null
#  SX56         | null
#  SX57         | null
#  TAVG         | 228
#  THIC         | null
#  TMAX         | 270
#  TMIN         | 167
#  TOBS         | null
#  TSUN         | null
#  WDF2         | null
#  WDF5         | null
#  WDFG         | null
#  WDMV         | null
#  WESD         | null
#  WESF         | null
#  WSF2         | null
#  WSF5         | null
#  WSFG         | null
#  WSFI         | null
#  WT01         | null
#  WT02         | null
#  WT03         | null
#  WT04         | null
#  WT05         | null
#  WT06         | null
#  WT07         | null
#  WT08         | null
#  WT09         | null
#  WT10         | null
#  WT11         | null
#  WT12         | null
#  WT13         | null
#  WT14         | null
#  WT15         | null
#  WT16         | null
#  WT17         | null
#  WT18         | null
#  WT19         | null
#  WT21         | null
#  WT22         | null
#  WV01         | null
#  WV03         | null
#  WV07         | null
#  WV18         | null
#  WV20         | null
#  YEAR         | 2000
#  MONTH        | 10
#  DAY          | 10
#  LATITUDE     | 34.983
#  LONGITUDE    | 138.4
#  ELEVATION    | 15.0
#  STATE        | null
#  NAME         | SHIZUOKA
#  GSN_FLAG     | null
#  HCN_CRN      | null
#  WMO_ID       | null
#  COUNTRY      | Japan
# -RECORD 3------------------------------------------------
#  COUNTRY_CODE | MX
#  ID           | MXN00031034
#  DATE         | 2000-02-22
#  M_FLAG       | null
#  Q_FLAG       | null
#  S_FLAG       | m
#  OBS_TIME     | null
#  filename     | s3a://noaa-ghcn-pds/csv/by_year/2000.csv
#  ACMH         | null
#  ACSH         | null
#  ADPT         | null
#  ASLP         | null
#  ASTP         | null
#  AWBT         | null
#  AWDR         | null
#  AWND         | null
#  DAEV         | null
#  DAPR         | null
#  DASF         | null
#  DATN         | null
#  DATX         | null
#  DAWM         | null
#  DWPR         | null
#  EVAP         | null
#  FMTM         | null
#  MDEV         | null
#  MDPR         | null
#  MDSF         | null
#  MDTN         | null
#  MDTX         | null
#  MDWM         | null
#  MNPN         | null
#  MXPN         | null
#  PGTM         | null
#  PRCP         | 0
#  PSUN         | null
#  RHAV         | null
#  RHMN         | null
#  RHMX         | null
#  SN01         | null
#  SN02         | null
#  SN03         | null
#  SN11         | null
#  SN12         | null
#  SN13         | null
#  SN14         | null
#  SN21         | null
#  SN22         | null
#  SN23         | null
#  SN31         | null
#  SN32         | null
#  SN33         | null
#  SN34         | null
#  SN35         | null
#  SN36         | null
#  SN51         | null
#  SN52         | null
#  SN53         | null
#  SN54         | null
#  SN55         | null
#  SN56         | null
#  SN57         | null
#  SNOW         | null
#  SNWD         | null
#  SX01         | null
#  SX02         | null
#  SX03         | null
#  SX11         | null
#  SX12         | null
#  SX13         | null
#  SX14         | null
#  SX15         | null
#  SX17         | null
#  SX21         | null
#  SX22         | null
#  SX23         | null
#  SX31         | null
#  SX32         | null
#  SX33         | null
#  SX34         | null
#  SX35         | null
#  SX36         | null
#  SX51         | null
#  SX52         | null
#  SX53         | null
#  SX54         | null
#  SX55         | null
#  SX56         | null
#  SX57         | null
#  TAVG         | null
#  THIC         | null
#  TMAX         | 294
#  TMIN         | 89
#  TOBS         | null
#  TSUN         | null
#  WDF2         | null
#  WDF5         | null
#  WDFG         | null
#  WDMV         | null
#  WESD         | null
#  WESF         | null
#  WSF2         | null
#  WSF5         | null
#  WSFG         | null
#  WSFI         | null
#  WT01         | null
#  WT02         | null
#  WT03         | null
#  WT04         | null
#  WT05         | null
#  WT06         | null
#  WT07         | null
#  WT08         | null
#  WT09         | null
#  WT10         | null
#  WT11         | null
#  WT12         | null
#  WT13         | null
#  WT14         | null
#  WT15         | null
#  WT16         | null
#  WT17         | null
#  WT18         | null
#  WT19         | null
#  WT21         | null
#  WT22         | null
#  WV01         | null
#  WV03         | null
#  WV07         | null
#  WV18         | null
#  WV20         | null
#  YEAR         | 2000
#  MONTH        | 2
#  DAY          | 22
#  LATITUDE     | 21.15
#  LONGITUDE    | -88.1667
#  ELEVATION    | 13.7
#  STATE        | null
#  NAME         | TIZIMIN
#  GSN_FLAG     | null
#  HCN_CRN      | null
#  WMO_ID       | null
#  COUNTRY      | Mexico
# -RECORD 4------------------------------------------------
#  COUNTRY_CODE | RS
#  ID           | RSM00030555
#  DATE         | 2000-10-12
#  M_FLAG       | null
#  Q_FLAG       | null
#  S_FLAG       | r
#  OBS_TIME     | null
#  filename     | s3a://noaa-ghcn-pds/csv/by_year/2000.csv
#  ACMH         | null
#  ACSH         | null
#  ADPT         | null
#  ASLP         | null
#  ASTP         | null
#  AWBT         | null
#  AWDR         | null
#  AWND         | null
#  DAEV         | null
#  DAPR         | null
#  DASF         | null
#  DATN         | null
#  DATX         | null
#  DAWM         | null
#  DWPR         | null
#  EVAP         | null
#  FMTM         | null
#  MDEV         | null
#  MDPR         | null
#  MDSF         | null
#  MDTN         | null
#  MDTX         | null
#  MDWM         | null
#  MNPN         | null
#  MXPN         | null
#  PGTM         | null
#  PRCP         | 0
#  PSUN         | null
#  RHAV         | null
#  RHMN         | null
#  RHMX         | null
#  SN01         | null
#  SN02         | null
#  SN03         | null
#  SN11         | null
#  SN12         | null
#  SN13         | null
#  SN14         | null
#  SN21         | null
#  SN22         | null
#  SN23         | null
#  SN31         | null
#  SN32         | null
#  SN33         | null
#  SN34         | null
#  SN35         | null
#  SN36         | null
#  SN51         | null
#  SN52         | null
#  SN53         | null
#  SN54         | null
#  SN55         | null
#  SN56         | null
#  SN57         | null
#  SNOW         | null
#  SNWD         | null
#  SX01         | null
#  SX02         | null
#  SX03         | null
#  SX11         | null
#  SX12         | null
#  SX13         | null
#  SX14         | null
#  SX15         | null
#  SX17         | null
#  SX21         | null
#  SX22         | null
#  SX23         | null
#  SX31         | null
#  SX32         | null
#  SX33         | null
#  SX34         | null
#  SX35         | null
#  SX36         | null
#  SX51         | null
#  SX52         | null
#  SX53         | null
#  SX54         | null
#  SX55         | null
#  SX56         | null
#  SX57         | null
#  TAVG         | -62
#  THIC         | null
#  TMAX         | 4
#  TMIN         | -190
#  TOBS         | null
#  TSUN         | null
#  WDF2         | null
#  WDF5         | null
#  WDFG         | null
#  WDMV         | null
#  WESD         | null
#  WESF         | null
#  WSF2         | null
#  WSF5         | null
#  WSFG         | null
#  WSFI         | null
#  WT01         | null
#  WT02         | null
#  WT03         | null
#  WT04         | null
#  WT05         | null
#  WT06         | null
#  WT07         | null
#  WT08         | null
#  WT09         | null
#  WT10         | null
#  WT11         | null
#  WT12         | null
#  WT13         | null
#  WT14         | null
#  WT15         | null
#  WT16         | null
#  WT17         | null
#  WT18         | null
#  WT19         | null
#  WT21         | null
#  WT22         | null
#  WV01         | null
#  WV03         | null
#  WV07         | null
#  WV18         | null
#  WV20         | null
#  YEAR         | 2000
#  MONTH        | 10
#  DAY          | 12
#  LATITUDE     | 54.6167
#  LONGITUDE    | null
#  ELEVATION    | null
#  STATE        | TROICKIJ PRIISK
#  NAME         | null
#  GSN_FLAG     | null
#  HCN_CRN      | null
#  WMO_ID       | null
#  COUNTRY      | Russia
# -RECORD 5------------------------------------------------
#  COUNTRY_CODE | SW
#  ID           | SWE00137664
#  DATE         | 2000-11-21
#  M_FLAG       | null
#  Q_FLAG       | null
#  S_FLAG       | E
#  OBS_TIME     | null
#  filename     | s3a://noaa-ghcn-pds/csv/by_year/2000.csv
#  ACMH         | null
#  ACSH         | null
#  ADPT         | null
#  ASLP         | null
#  ASTP         | null
#  AWBT         | null
#  AWDR         | null
#  AWND         | null
#  DAEV         | null
#  DAPR         | null
#  DASF         | null
#  DATN         | null
#  DATX         | null
#  DAWM         | null
#  DWPR         | null
#  EVAP         | null
#  FMTM         | null
#  MDEV         | null
#  MDPR         | null
#  MDSF         | null
#  MDTN         | null
#  MDTX         | null
#  MDWM         | null
#  MNPN         | null
#  MXPN         | null
#  PGTM         | null
#  PRCP         | 84
#  PSUN         | null
#  RHAV         | null
#  RHMN         | null
#  RHMX         | null
#  SN01         | null
#  SN02         | null
#  SN03         | null
#  SN11         | null
#  SN12         | null
#  SN13         | null
#  SN14         | null
#  SN21         | null
#  SN22         | null
#  SN23         | null
#  SN31         | null
#  SN32         | null
#  SN33         | null
#  SN34         | null
#  SN35         | null
#  SN36         | null
#  SN51         | null
#  SN52         | null
#  SN53         | null
#  SN54         | null
#  SN55         | null
#  SN56         | null
#  SN57         | null
#  SNOW         | null
#  SNWD         | null
#  SX01         | null
#  SX02         | null
#  SX03         | null
#  SX11         | null
#  SX12         | null
#  SX13         | null
#  SX14         | null
#  SX15         | null
#  SX17         | null
#  SX21         | null
#  SX22         | null
#  SX23         | null
#  SX31         | null
#  SX32         | null
#  SX33         | null
#  SX34         | null
#  SX35         | null
#  SX36         | null
#  SX51         | null
#  SX52         | null
#  SX53         | null
#  SX54         | null
#  SX55         | null
#  SX56         | null
#  SX57         | null
#  TAVG         | null
#  THIC         | null
#  TMAX         | null
#  TMIN         | null
#  TOBS         | null
#  TSUN         | null
#  WDF2         | null
#  WDF5         | null
#  WDFG         | null
#  WDMV         | null
#  WESD         | null
#  WESF         | null
#  WSF2         | null
#  WSF5         | null
#  WSFG         | null
# ...
#  ASTP         | null
#  AWBT         | null
#  AWDR         | null
#  AWND         | null
#  DAEV         | null
#  DAPR         | null
#  DASF         | null
#  DATN         | null
#  DATX         | null
#  DAWM         | null
#  DWPR         | null
#  EVAP         | null
#  FMTM         | null
#  MDEV         | null
#  MDPR         | null
#  MDSF         | null
#  MDTN         | null
#  MDTX         | null
#  MDWM         | null
#  MNPN         | null
#  MXPN         | null
#  PGTM         | null
#  PRCP         | 0
#  PSUN         | null
#  RHAV         | null
#  RHMN         | null
#  RHMX         | null
#  SN01         | null
#  SN02         | null
#  SN03         | null
#  SN11         | null
#  SN12         | null
#  SN13         | null
#  SN14         | null
#  SN21         | null
#  SN22         | null
#  SN23         | null
#  SN31         | null
#  SN32         | null
#  SN33         | null
#  SN34         | null
#  SN35         | null
#  SN36         | null
#  SN51         | null
#  SN52         | null
#  SN53         | null
#  SN54         | null
#  SN55         | null
#  SN56         | null
#  SN57         | null
#  SNOW         | 0
#  SNWD         | 533
#  SX01         | null
#  SX02         | null
#  SX03         | null
#  SX11         | null
#  SX12         | null
#  SX13         | null
#  SX14         | null
#  SX15         | null
#  SX17         | null
#  SX21         | null
#  SX22         | null
#  SX23         | null
#  SX31         | null
#  SX32         | null
#  SX33         | null
#  SX34         | null
#  SX35         | null
#  SX36         | null
#  SX51         | null
#  SX52         | null
#  SX53         | null
#  SX54         | null
#  SX55         | null
#  SX56         | null
#  SX57         | null
#  TAVG         | null
#  THIC         | null
#  TMAX         | -33
#  TMIN         | -289
#  TOBS         | -61
#  TSUN         | null
#  WDF2         | null
#  WDF5         | null
#  WDFG         | null
#  WDMV         | null
#  WESD         | null
#  WESF         | null
#  WSF2         | null
#  WSF5         | null
#  WSFG         | null
#  WSFI         | null
#  WT01         | null
#  WT02         | null
#  WT03         | null
#  WT04         | null
#  WT05         | null
#  WT06         | null
#  WT07         | null
#  WT08         | null
#  WT09         | null
#  WT10         | null
#  WT11         | null
#  WT12         | null
#  WT13         | null
#  WT14         | null
#  WT15         | null
#  WT16         | null
#  WT17         | null
#  WT18         | null
#  WT19         | null
#  WT21         | null
#  WT22         | null
#  WV01         | null
#  WV03         | null
#  WV07         | null
#  WV18         | null
#  WV20         | null
#  YEAR         | 2001
#  MONTH        | 3
#  DAY          | 4
#  LATITUDE     | 46.4283
#  LONGITUDE    | -67.8442
#  ELEVATION    | null
#  STATE        | null
#  NAME         | null
#  GSN_FLAG     | null
#  HCN_CRN      | null
#  WMO_ID       | null
#  COUNTRY      | United
# -RECORD 19-----------------------------------------------
#  COUNTRY_CODE | US
#  ID           | USC00212486
#  DATE         | 2001-04-28
#  M_FLAG       | null
#  Q_FLAG       | null
#  S_FLAG       | 0
#  OBS_TIME     | 0700
#  filename     | s3a://noaa-ghcn-pds/csv/by_year/2001.csv
#  ACMH         | null
#  ACSH         | null
#  ADPT         | null
#  ASLP         | null
#  ASTP         | null
#  AWBT         | null
#  AWDR         | null
#  AWND         | null
#  DAEV         | null
#  DAPR         | null
#  DASF         | null
#  DATN         | null
#  DATX         | null
#  DAWM         | null
#  DWPR         | null
#  EVAP         | null
#  FMTM         | null
#  MDEV         | null
#  MDPR         | null
#  MDSF         | null
#  MDTN         | null
#  MDTX         | null
#  MDWM         | null
#  MNPN         | null
#  MXPN         | null
#  PGTM         | null
#  PRCP         | 0
#  PSUN         | null
#  RHAV         | null
#  RHMN         | null
#  RHMX         | null
#  SN01         | null
#  SN02         | null
#  SN03         | null
#  SN11         | null
#  SN12         | null
#  SN13         | null
#  SN14         | null
#  SN21         | null
#  SN22         | null
#  SN23         | null
#  SN31         | null
#  SN32         | null
#  SN33         | null
#  SN34         | null
#  SN35         | null
#  SN36         | null
#  SN51         | null
#  SN52         | null
#  SN53         | null
#  SN54         | null
#  SN55         | null
#  SN56         | null
#  SN57         | null
#  SNOW         | 0
#  SNWD         | 0
#  SX01         | null
#  SX02         | null
#  SX03         | null
#  SX11         | null
#  SX12         | null
#  SX13         | null
#  SX14         | null
#  SX15         | null
#  SX17         | null
#  SX21         | null
#  SX22         | null
#  SX23         | null
#  SX31         | null
#  SX32         | null
#  SX33         | null
#  SX34         | null
#  SX35         | null
#  SX36         | null
#  SX51         | null
#  SX52         | null
#  SX53         | null
#  SX54         | null
#  SX55         | null
#  SX56         | null
#  SX57         | null
#  TAVG         | null
#  THIC         | null
#  TMAX         | null
#  TMIN         | null
#  TOBS         | null
#  TSUN         | null
#  WDF2         | null
#  WDF5         | null
#  WDFG         | null
#  WDMV         | null
#  WESD         | null
#  WESF         | null
#  WSF2         | null
#  WSF5         | null
#  WSFG         | null
#  WSFI         | null
#  WT01         | null
#  WT02         | null
#  WT03         | null
#  WT04         | null
#  WT05         | null
#  WT06         | null
#  WT07         | null
#  WT08         | null
#  WT09         | null
#  WT10         | null
#  WT11         | null
#  WT12         | null
#  WT13         | null
#  WT14         | null
#  WT15         | null
#  WT16         | null
#  WT17         | null
#  WT18         | null
#  WT19         | null
#  WT21         | null
#  WT22         | null
#  WV01         | null
#  WV03         | null
#  WV07         | null
#  WV18         | null
#  WV20         | null
#  YEAR         | 2001
#  MONTH        | 4
#  DAY          | 28
#  LATITUDE     | 44.0969
#  LONGITUDE    | -92.2703
#  ELEVATION    | null
#  STATE        | null
#  NAME         | null
#  GSN_FLAG     | null
#  HCN_CRN      | null
#  WMO_ID       | null
#  COUNTRY      | United
# only showing top 20 rows

# %% [markdown]
# # Check saved data

# %% [markdown]
# ## Countries

# %%
in_fpath = f"s3://bdcc-lab2-2023/ghcnd/ghcnd_countries.csv"
df_countries= (spark.read.csv(in_fpath, header=True, inferSchema=True))

df_countries.show(truncate=False)

# %% [markdown]
# ## Raw

# %%
in_fpath = f"s3://bdcc-lab2-2023/ghcnd/ghcnd_raw.parquet"
df_raw = spark.read.parquet(in_fpath)

# %%
df_raw.count()

# %%
df.show(truncate=False)

# %%
df.printSchema()

# %%
# checker
(df.agg(F.countDistinct('ID').alias('unique_count'), F.count('ID').alias('total_count'))).show()

# %% [markdown]
# -End of Data Preparation Notebook-
